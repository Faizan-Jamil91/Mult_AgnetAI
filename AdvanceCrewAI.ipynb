# %% [markdown]
# ### Automated Project : Planning Estimation and Allocation.

# %%
from crewai import Agent, Task, Crew, LLM

# %%
from langchain_groq import ChatGroq

# %%
import os

# %%
LLAMA = os.environ['GROQ_API_KEY'] = "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"

# %%
llm = LLM(
    model="groq/llama-3.1-70b-versatile",
    temperature=0.5,
    max_tokens=1024,
    top_p=0.9,
    stop=None,
    stream=False,
)

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
#from helper import load_env
#load_env()

import os
import yaml

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent'],
  llm=llm,
)

estimation_agent = Agent(
  config=agents_config['estimation_agent'],
  llm=llm,
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent'],
  llm=llm,
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %%
print("Agents config:", agents_config)
print("Tasks config:", tasks_config)
# Out:
# Agents config: {'project_planning_agent': {'role': 'The Ultimate Project Planner\n', 'goal': 'To meticulously break down the {project_type} project into actionable tasks, ensuring no detail is overlooked, and setting precise timelines that align with the {project_objectives}.\n', 'backstory': "As a veteran project manager, youâ€™ve led numerous successful projects, particularly in {industry}. Your keen eye for detail and strategic thinking have always ensured that projects are delivered on time and within scope. Now, you're tasked with planning the next groundbreaking {project_type} project.\n", 'allow_delegation': False, 'verbose': True, 'llm': 'groq_llm'}, 'estimation_agent': {'role': 'Expert Estimation Analyst\n', 'goal': 'Provide highly accurate time, resource, and effort estimations for each task in the {project_type} project to ensure it is delivered efficiently and on budget.\n', 'backstory': 'You are the go-to expert for project estimation in {industry}. With a wealth of experience and access to vast historical data, you can predict the resources required for any task with remarkable accuracy. Your precision ensures that the {project_type} project remains feasible and avoids unnecessary delays or budget overruns.\n', 'allow_delegation': False, 'verbose': True, 'llm': 'groq_llm'}, 'resource_allocation_agent': {'role': 'Resource Allocation Strategist\n', 'goal': "Optimize the allocation of tasks for the {project_type} project by balancing team members' skills, availability, and current workload to maximize efficiency and project success.\n", 'backstory': 'With a deep understanding of team dynamics and resource management in {industry}, you have a track record of ensuring that the right person is always assigned to the right task. Your strategic thinking ensures that the {project_type} project team is utilized to its full potential without overburdening any individual.\n', 'allow_delegation': False, 'verbose': True, 'llm': 'groq_llm'}}
# Tasks config: {'task_breakdown': {'description': "Carefully analyze the project_requirements for the {project_type} project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:\n{project_requirements}\n\nTeam members:\n{team_members}\n", 'expected_output': 'A comprehensive list of tasks with detailed descriptions, timelines, dependencies, and deliverables. Your final output MUST include a Gantt chart or similar timeline visualization specific to the {project_type} project.\n'}, 'time_resource_estimation': {'description': 'Thoroughly evaluate each task in the {project_type} project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.\n', 'expected_output': 'A detailed estimation report outlining the time, resources, and effort required for each task in the {project_type} project. Your final report MUST include a summary of any risks or uncertainties associated with the estimations.\n'}, 'resource_allocation': {'description': 'Strategically allocate tasks for the {project_type} project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.\n\nTeam members:\n{team_members}\n', 'expected_output': 'A resource allocation chart showing which team members are responsible for each task in the {project_type} project, along with start and end dates. Your final output MUST also include a summary explaining the rationale behind each allocation decision.\n'}}

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
# response: <Response [200 OK]>
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Website Project Plan**
#
# **Task 1: Project Kickoff and Planning**
#
# * Description: Define project scope, goals, and timelines. Identify team members and their roles.
# * Timeline: 2 days
# * Dependencies: None
# * Deliverables: Project plan document, team roles and responsibilities document
# * Assignee: John Doe (Project Manager)
#
# **Task 2: Design Concept and Wireframing**
#
# * Description: Create a responsive design concept and wireframes for the website.
# * Timeline: 5 days
# * Dependencies: Task 1
# * Deliverables: Design concept document, wireframes for desktop and mobile devices
# * Assignee: Bob Smith (Designer)
#
# **Task 3: Visual Design and UI Development**
#
# * Description: Develop a modern, visually appealing user interface with a clean look.
# * Timeline: 7 days
# * Dependencies: Task 2
# * Deliverables: Visual design concept document, UI components (e.g., buttons, icons)
# * Assignee: Bob Smith (Designer)
#
# **Task 4: Navigation System Development**
#
# * Description: Develop a user-friendly navigation system with an intuitive menu structure.
# * Timeline: 3 days
# * Dependencies: Task 3
# * Deliverables: Navigation system prototype, menu structure document
# * Assignee: Jane Doe (Software Engineer)
#
# **Task 5: About Us Page Development**
#
# * Description: Create an "About Us" page highlighting the company's history and values.
# * Timeline: 2 days
# * Dependencies: Task 3, Task 4
# * Deliverables: About Us page content, page design and layout
# * Assignee: Jane Doe (Software Engineer)
#
# **Task 6: Services Page Development**
#
# * Description: Design a "Services" page showcasing the business's offerings with descriptions.
# * Timeline: 2 days
# * Dependencies: Task 3, Task 4
# * Deliverables: Services page content, page design and layout
# * Assignee: Jane Doe (Software Engineer)
#
# **Task 7: Contact Us Page Development**
#
# * Description: Create a "Contact Us" page with a form and integrated map for communication.
# * Timeline: 3 days
# * Dependencies: Task 3, Task 4
# * Deliverables: Contact Us page content, page design and layout, form functionality
# * Assignee: Jane Doe (Software Engineer)
#
# **Task 8: Blog Section Development**
#
# * Description: Implement a blog section for sharing industry news and company updates.
# * Timeline: 4 days
# * Dependencies: Task 3, Task 4
# * Deliverables: Blog section prototype, blog post template
# * Assignee: Jane Doe (Software Engineer)
#
# **Task 9: SEO Optimization**
#
# * Description: Ensure fast loading times and optimize the website for search engines (SEO).
# * Timeline: 4 days
# * Dependencies: Task 8
# * Deliverables: SEO audit report, optimized website code
# * Assignee: Jane Doe (Software Engineer)
#
# **Task 10: Social Media Integration**
#
# * Description: Integrate social media links and sharing capabilities.
# * Timeline: 2 days
# * Dependencies: Task 8
# * Deliverables: Social media links and sharing functionality
# * Assignee: Jane Doe (Software Engineer)
#
# **Task 11: Testimonials Section Development**
#
# * Description: Include a testimonials section to showcase customer feedback and build trust.
# * Timeline: 2 days
# * Dependencies: Task 8
# * Deliverables: Testimonials section prototype, customer feedback content
# * Assignee: Jane Doe (Software Engineer)
#
# **Task 12: Quality Assurance (QA) and Testing**
#
# * Description: Conduct thorough QA and testing of the website.
# * Timeline: 7 days
# * Dependencies: Task 11
# * Deliverables: QA test plan document, test results report
# * Assignee: Alice Johnson (QA Engineer), Tom Brown (QA Engineer)
#
# **Task 13: Launch and Deployment**
#
# * Description: Launch and deploy the website to production.
# * Timeline: 2 days
# * Dependencies: Task 12
# * Deliverables: Live website, deployment report
# * Assignee: Jane Doe (Software Engineer)
#
# **Gantt Chart:**
#
# | Task | Start Date | End Date | Duration | Dependencies |
# | --- | --- | --- | --- | --- |
# | Task 1 | 2024-09-01 | 2024-09-02 | 2 days | - |
# | Task 2 | 2024-09-03 | 2024-09-07 | 5 days | Task 1 |
# | Task 3 | 2024-09-08 | 2024-09-14 | 7 days | Task 2 |
# | Task 4 | 2024-09-15 | 2024-09-17 | 3 days | Task 3 |
# | Task 5 | 2024-09-18 | 2024-09-19 | 2 days | Task
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
# response: <Response [200 OK]>
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# **Detailed Estimation Report for Website Project**
#
# **Introduction:**
# This report provides a thorough evaluation of each task in the Website project, estimating the time, resources, and effort required to complete each task. The estimations are based on historical data, task complexity, and available resources. The report also includes a summary of any risks or uncertainties associated with the estimations.
#
# **Task 1: Project Kickoff and Planning**
#
# * Estimated Time: 2 days
# * Estimated Resources: John Doe (Project Manager)
# * Estimated Effort: 16 hours
# * Dependencies: None
# * Deliverables: Project plan document, team roles and responsibilities document
# * Risks and Uncertainties: None
#
# **Task 2: Design Concept and Wireframing**
#
# * Estimated Time: 5 days
# * Estimated Resources: Bob Smith (Designer)
# * Estimated Effort: 40 hours
# * Dependencies: Task 1
# * Deliverables: Design concept document, wireframes for desktop and mobile devices
# * Risks and Uncertainties: Design concept may require multiple iterations, potentially delaying the project timeline.
#
# **Task 3: Visual Design and UI Development**
#
# * Estimated Time: 7 days
# * Estimated Resources: Bob Smith (Designer)
# * Estimated Effort: 56 hours
# * Dependencies: Task 2
# * Deliverables: Visual design concept document, UI components (e.g., buttons, icons)
# * Risks and Uncertainties: Visual design may require multiple iterations, potentially delaying the project timeline.
#
# **Task 4: Navigation System Development**
#
# * Estimated Time: 3 days
# * Estimated Resources: Jane Doe (Software Engineer)
# * Estimated Effort: 24 hours
# * Dependencies: Task 3
# * Deliverables: Navigation system prototype, menu structure document
# * Risks and Uncertainties: Navigation system development may require additional time for testing and debugging.
#
# **Task 5: About Us Page Development**
#
# * Estimated Time: 2 days
# * Estimated Resources: Jane Doe (Software Engineer)
# * Estimated Effort: 16 hours
# * Dependencies: Task 3, Task 4
# * Deliverables: About Us page content, page design and layout
# * Risks and Uncertainties: Page development may require additional time for content creation and review.
#
# **Task 6: Services Page Development**
#
# * Estimated Time: 2 days
# * Estimated Resources: Jane Doe (Software Engineer)
# * Estimated Effort: 16 hours
# * Dependencies: Task 3, Task 4
# * Deliverables: Services page content, page design and layout
# * Risks and Uncertainties: Page development may require additional time for content creation and review.
#
# **Task 7: Contact Us Page Development**
#
# * Estimated Time: 3 days
# * Estimated Resources: Jane Doe (Software Engineer)
# * Estimated Effort: 24 hours
# * Dependencies: Task 3, Task 4
# * Deliverables: Contact Us page content, page design and layout, form functionality
# * Risks and Uncertainties: Form functionality may require additional time for testing and debugging.
#
# **Task 8: Blog Section Development**
#
# * Estimated Time: 4 days
# * Estimated Resources: Jane Doe (Software Engineer)
# * Estimated Effort: 32 hours
# * Dependencies: Task 3, Task 4
# * Deliverables: Blog section prototype, blog post template
# * Risks and Uncertainties: Blog section development may require additional time for testing and debugging.
#
# **Task 9: SEO Optimization**
#
# * Estimated Time: 4 days
# * Estimated Resources: Jane Doe (Software Engineer)
# * Estimated Effort: 32 hours
# * Dependencies: Task 8
# * Deliverables: SEO audit report, optimized website code
# * Risks and Uncertainties: SEO optimization may require additional time for testing and debugging.
#
# **Task 10: Social Media Integration**
#
# * Estimated Time: 2 days
# * Estimated Resources: Jane Doe (Software Engineer)
# * Estimated Effort: 16 hours
# * Dependencies: Task 8
# * Deliverables: Social media links and sharing functionality
# * Risks and Uncertainties: Social media integration may require additional time for testing and debugging.
#
# **Task 11: Testimonials Section Development**
#
# * Estimated Time: 2 days
# * Estimated Resources: Jane Doe (Software Engineer)
# * Estimated Effort: 16 hours
# * Dependencies: Task 8
# * Deliverables: Testimonials section prototype, customer feedback content
# * Risks and Uncertainties: Testimonials section development may require additional time for content creation and review.
#
# **Task 12: Quality Assurance (QA) and Testing**
#
# * Estimated Time: 7 days
# * Estimated Resources: Alice Johnson (QA Engineer), Tom Brown (QA Engineer)
# * Estimated Effort: 112 hours
# * Dependencies: Task 11
# * Deliverables: QA test plan document, test results report
# * Risks and Uncertainties: QA and testing may require
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
# response: <Response [200 OK]>
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# {
#   "tasks": [
#     {
#       "task_name": "Project Kickoff and Planning",
#       "estimated_time_hours": 16,
#       "required_resources": ["John Doe"],
#       "start_date": "2024-09-01",
#       "end_date": "2024-09-03"
#     },
#     {
#       "task_name": "Design Concept and Wireframing",
#       "estimated_time_hours": 40,
#       "required_resources": ["Bob Smith"],
#       "start_date": "2024-09-04",
#       "end_date": "2024-09-09"
#     },
#     {
#       "task_name": "Visual Design and UI Development",
#       "estimated_time_hours": 56,
#       "required_resources": ["Bob Smith"],
#       "start_date": "2024-09-10",
#       "end_date": "2024-09-17"
#     },
#     {
#       "task_name": "Navigation System Development",
#       "estimated_time_hours": 24,
#       "required_resources": ["Jane Doe"],
#       "start_date": "2024-09-18",
#       "end_date": "2024-09-21"
#     },
#     {
#       "task_name": "About Us Page Development",
#       "estimated_time_hours": 16,
#       "required_resources": ["Jane Doe"],
#       "start_date": "2024-09-22",
#       "end_date": "2024-09-24"
#     },
#     {
#       "task_name": "Services Page Development",
#       "estimated_time_hours": 16,
#       "required_resources": ["Jane Doe"],
#       "start_date": "2024-09-25",
#       "end_date": "2024-09-27"
#     },
#     {
#       "task_name": "Contact Us Page Development",
#       "estimated_time_hours": 24,
#       "required_resources": ["Jane Doe"],
#       "start_date": "2024-09-28",
#       "end_date": "2024-10-01"
#     },
#     {
#       "task_name": "Blog Section Development",
#       "estimated_time_hours": 32,
#       "required_resources": ["Jane Doe"],
#       "start_date": "2024-10-02",
#       "end_date": "2024-10-06"
#     },
#     {
#       "task_name": "SEO Optimization",
#       "estimated_time_hours": 32,
#       "required_resources": ["Jane Doe"],
#       "start_date": "2024-10-07",
#       "end_date": "2024-10-11"
#     },
#     {
#       "task_name": "Social Media Integration",
#       "estimated_time_hours": 16,
#       "required_resources": ["Jane Doe"],
#       "start_date": "2024-10-12",
#       "end_date": "2024-10-14"
#     },
#     {
#       "task_name": "Testimonials Section Development",
#       "estimated_time_hours": 16,
#       "required_resources": ["Jane Doe"],
#       "start_date": "2024-10-15",
#       "end_date": "2024-10-17"
#     },
#     {
#       "task_name": "Quality Assurance (QA) and Testing",
#       "estimated_time_hours": 112,
#       "required_resources": ["Alice Johnson", "Tom Brown"],
#       "start_date": "2024-10-18",
#       "end_date": "2024-10-25"
#     }
#   ],
#   "milestones": [
#     {
#       "milestone_name": "Project Kickoff",
#       "tasks": ["Project Kickoff and Planning"]
#     },
#     {
#       "milestone_name": "Design Completion",
#       "tasks": ["Design Concept and Wireframing", "Visual Design and UI Development"]
#     },
#     {
#       "milestone_name": "Page Development Completion",
#       "tasks": ["Navigation System Development", "About Us Page Development", "Services Page Development", "Contact Us Page Development", "Blog Section Development"]
#     },
#     {
#       "milestone_name": "SEO and Social Media Integration",
#       "tasks": ["SEO Optimization", "Social Media Integration"]
#     },
#     {
#       "milestone_name": "Testimonials and QA Completion",
#       "tasks": ["Testimonials Section Development", "Quality Assurance (QA) and Testing"]
#     }
#   ]
# }

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0009
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          6293           3331                     0               2962
#
#    successful_requests
# 0                    3

# %%
import pandas as pd

# Check if usage_metrics is a dictionary or an object
if isinstance(crew.usage_metrics, dict):
    # Calculate costs assuming it's a dictionary
    costs = 0.150 * (crew.usage_metrics['prompt_tokens'] + crew.usage_metrics['completion_tokens']) / 1_000_000
    df_usage_metrics = pd.DataFrame([crew.usage_metrics])

else:
    # Assume usage_metrics is an object with attributes
    costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
    df_usage_metrics = pd.DataFrame([crew.usage_metrics.__dict__])

# Print costs and DataFrame
print(f"Total costs: ${costs:.4f}")
print(df_usage_metrics)
# Out:
# Total costs: $0.0009
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          6293           3331                     0               2962
#
#    successful_requests
# 0                    3

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Project Kickoff and Planning',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Design Concept and Wireframing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Visual Design and UI Development',
#    'estimated_time_hours': 56.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Navigation System Development',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'About Us Page Development',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Services Page Development',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Contact Us Page Development',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Blog Section Development',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'SEO Optimization',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Social Media Integration',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Testimonials Section Development',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Quality Assurance (QA) and Testing',
#    'estimated_time_hours': 112.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']}],
#  'milestones': [{'milestone_name': 'Project Kickoff',
#    'tasks': ['Project Kickoff and Planning']},
#   {'milestone_name': 'Design Completion',
#    'tasks': ['Design Concept and Wireframing',
#     'Visual Design and UI Development']},
#   {'milestone_name': 'Page Development Completion',
#    'tasks': ['Navigation System Development',
#     'About Us Page Development',
#     'Services Page Development',
#     'Contact Us Page Development',
#     'Blog Section Development']},
#   {'milestone_name': 'SEO and Social Media Integration',
#    'tasks': ['SEO Optimization', 'Social Media Integration']},
#   {'milestone_name': 'Testimonials and QA Completion',
#    'tasks': ['Testimonials Section Development',
#     'Quality Assurance (QA) and Testing']}]}

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_cb74a th {
#   font-size: 120%;
# }
# #T_cb74a  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_cb74a" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb74a_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_cb74a_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_cb74a_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb74a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb74a_row0_col0" class="data row0 col0" >Project Kickoff and Planning</td>
#       <td id="T_cb74a_row0_col1" class="data row0 col1" >16.000000</td>
#       <td id="T_cb74a_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb74a_row1_col0" class="data row1 col0" >Design Concept and Wireframing</td>
#       <td id="T_cb74a_row1_col1" class="data row1 col1" >40.000000</td>
#       <td id="T_cb74a_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb74a_row2_col0" class="data row2 col0" >Visual Design and UI Development</td>
#       <td id="T_cb74a_row2_col1" class="data row2 col1" >56.000000</td>
#       <td id="T_cb74a_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb74a_row3_col0" class="data row3 col0" >Navigation System Development</td>
#       <td id="T_cb74a_row3_col1" class="data row3 col1" >24.000000</td>
#       <td id="T_cb74a_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb74a_row4_col0" class="data row4 col0" >About Us Page Development</td>
#       <td id="T_cb74a_row4_col1" class="data row4 col1" >16.000000</td>
#       <td id="T_cb74a_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb74a_row5_col0" class="data row5 col0" >Services Page Development</td>
#       <td id="T_cb74a_row5_col1" class="data row5 col1" >16.000000</td>
#       <td id="T_cb74a_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb74a_row6_col0" class="data row6 col0" >Contact Us Page Development</td>
#       <td id="T_cb74a_row6_col1" class="data row6 col1" >24.000000</td>
#       <td id="T_cb74a_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb74a_row7_col0" class="data row7 col0" >Blog Section Development</td>
#       <td id="T_cb74a_row7_col1" class="data row7 col1" >32.000000</td>
#       <td id="T_cb74a_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cb74a_row8_col0" class="data row8 col0" >SEO Optimization</td>
#       <td id="T_cb74a_row8_col1" class="data row8 col1" >32.000000</td>
#       <td id="T_cb74a_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cb74a_row9_col0" class="data row9 col0" >Social Media Integration</td>
#       <td id="T_cb74a_row9_col1" class="data row9 col1" >16.000000</td>
#       <td id="T_cb74a_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cb74a_row10_col0" class="data row10 col0" >Testimonials Section Development</td>
#       <td id="T_cb74a_row10_col1" class="data row10 col1" >16.000000</td>
#       <td id="T_cb74a_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_cb74a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cb74a_row11_col0" class="data row11 col0" >Quality Assurance (QA) and Testing</td>
#       <td id="T_cb74a_row11_col1" class="data row11 col1" >112.000000</td>
#       <td id="T_cb74a_row11_col2" class="data row11 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#   </tbody>
# </table>

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_ec4d2 th {
#   font-size: 120%;
# }
# #T_ec4d2  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_ec4d2" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec4d2_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_ec4d2_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec4d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec4d2_row0_col0" class="data row0 col0" >Project Kickoff</td>
#       <td id="T_ec4d2_row0_col1" class="data row0 col1" >['Project Kickoff and Planning']</td>
#     </tr>
#     <tr>
#       <th id="T_ec4d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec4d2_row1_col0" class="data row1 col0" >Design Completion</td>
#       <td id="T_ec4d2_row1_col1" class="data row1 col1" >['Design Concept and Wireframing', 'Visual Design and UI Development']</td>
#     </tr>
#     <tr>
#       <th id="T_ec4d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec4d2_row2_col0" class="data row2 col0" >Page Development Completion</td>
#       <td id="T_ec4d2_row2_col1" class="data row2 col1" >['Navigation System Development', 'About Us Page Development', 'Services Page Development', 'Contact Us Page Development', 'Blog Section Development']</td>
#     </tr>
#     <tr>
#       <th id="T_ec4d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec4d2_row3_col0" class="data row3 col0" >SEO and Social Media Integration</td>
#       <td id="T_ec4d2_row3_col1" class="data row3 col1" >['SEO Optimization', 'Social Media Integration']</td>
#     </tr>
#     <tr>
#       <th id="T_ec4d2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ec4d2_row4_col0" class="data row4 col0" >Testimonials and QA Completion</td>
#       <td id="T_ec4d2_row4_col1" class="data row4 col1" >['Testimonials Section Development', 'Quality Assurance (QA) and Testing']</td>
#     </tr>
#   </tbody>
# </table>
